# %%
pip install mysql.connector

# %%
import pandas as pd
import numpy as np
import mysql.connector
from datetime import datetime

# %%
data = pd.read_csv("POLICE.CSV.csv")
# Out:
# C:\Users\A Prem kumar\AppData\Local\Temp\ipykernel_14900\1196067730.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("POLICE.CSV.csv")

# %%
data
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      01-01-2020  00:00:00       Canada             M              59
# 1      01-01-2020  00:01:00        India             M              35
# 2      01-01-2020  00:02:00          USA             M              26
# 3      01-01-2020  00:03:00       Canada             M              26
# 4      01-01-2020  00:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  15-02-2020  12:13:00        India             F              54
# 65534  15-02-2020  12:14:00       Canada             F              18
# 65535  15-02-2020  12:15:00          USA             M              27
# 65536  15-02-2020  12:16:00       Canada             F              49
# 65537  15-02-2020  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
data.dropna(axis=1, how= 'all', inplace= True)

# %%
data
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      01-01-2020  00:00:00       Canada             M              59
# 1      01-01-2020  00:01:00        India             M              35
# 2      01-01-2020  00:02:00          USA             M              26
# 3      01-01-2020  00:03:00       Canada             M              26
# 4      01-01-2020  00:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  15-02-2020  12:13:00        India             F              54
# 65534  15-02-2020  12:14:00       Canada             F              18
# 65535  15-02-2020  12:15:00          USA             M              27
# 65536  15-02-2020  12:16:00       Canada             F              49
# 65537  15-02-2020  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
data.fillna({
     'driver_age': data['driver_age'].median(),
     'search_type':'No',
     'stop_duration': 'unknown',
     'violation': 'unknown',
     'stop_outcome': 'unknown',
}, inplace=True)

# %%
data
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      01-01-2020  00:00:00       Canada             M              59
# 1      01-01-2020  00:01:00        India             M              35
# 2      01-01-2020  00:02:00          USA             M              26
# 3      01-01-2020  00:03:00       Canada             M              26
# 4      01-01-2020  00:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  15-02-2020  12:13:00        India             F              54
# 65534  15-02-2020  12:14:00       Canada             F              18
# 65535  15-02-2020  12:15:00          USA             M              27
# 65536  15-02-2020  12:16:00       Canada             F              49
# 65537  15-02-2020  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
data.drop('driver_age_raw', axis=1, inplace=True)

# %%
data.drop('violation_raw', axis=1, inplace= True)

# %%
data
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      01-01-2020  00:00:00       Canada             M          19
# 1      01-01-2020  00:01:00        India             M          58
# 2      01-01-2020  00:02:00          USA             M          76
# 3      01-01-2020  00:03:00       Canada             M          76
# 4      01-01-2020  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  15-02-2020  12:13:00        India             F          48
# 65534  15-02-2020  12:14:00       Canada             F          35
# 65535  15-02-2020  12:15:00          USA             M          41
# 65536  15-02-2020  12:16:00       Canada             F          63
# 65537  15-02-2020  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
data['timestamp'] = pd.to_datetime(data['stop_date'].astype(str) + ' ' + data['stop_time'].astype(str), errors='coerce')

# %%
data
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      01-01-2020  00:00:00       Canada             M          19
# 1      01-01-2020  00:01:00        India             M          58
# 2      01-01-2020  00:02:00          USA             M          76
# 3      01-01-2020  00:03:00       Canada             M          76
# 4      01-01-2020  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  15-02-2020  12:13:00        India             F          48
# 65534  15-02-2020  12:14:00       Canada             F          35
# 65535  15-02-2020  12:15:00          USA             M          41
# 65536  15-02-2020  12:16:00       Canada             F          63
# 65537  15-02-2020  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
data
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      01-01-2020  00:00:00       Canada             M          19
# 1      01-01-2020  00:01:00        India             M          58
# 2      01-01-2020  00:02:00          USA             M          76
# 3      01-01-2020  00:03:00       Canada             M          76
# 4      01-01-2020  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  15-02-2020  12:13:00        India             F          48
# 65534  15-02-2020  12:14:00       Canada             F          35
# 65535  15-02-2020  12:15:00          USA             M          41
# 65536  15-02-2020  12:16:00       Canada             F          63
# 65537  15-02-2020  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
import pymysql

conn = pymysql.connect(
    host="localhost",
    user="root",
    password="root",
    database="securecheck"
)

# %%
conn = pymysql.connect(
    host="localhost",
    user="root",
    password="root",
    database= "securecheck",
)

# %%
import mysql.connector

# %%
cursor = conn.cursor()

cursor.execute("USE securecheck;")
# Out:
# 0

# %%
cursor.execute("""CREATE TABLE IF NOT EXISTS police_logs (
    id INT AUTO_INCREMENT PRIMARY KEY,
    stop_date DATE,
    stop_time TIME,
    country_name VARCHAR(100),
    driver_gender VARCHAR(10),
    driver_age INT,
    driver_race VARCHAR(50),
    violation VARCHAR(100),
    search_conducted BOOLEAN,
    search_type VARCHAR(100),
    stop_outcome VARCHAR(100),
    drugs_related_stop BOOLEAN,
    stop_duration VARCHAR(50),
    vehicle_number VARCHAR(50),
    timestamp DATETIME               
)""")
# Out:
# 0

# %%
data
# Out:
#         stop_date stop_time country_name driver_gender  driver_age  \
# 0      01-01-2020  00:00:00       Canada             M          19
# 1      01-01-2020  00:01:00        India             M          58
# 2      01-01-2020  00:02:00          USA             M          76
# 3      01-01-2020  00:03:00       Canada             M          76
# 4      01-01-2020  00:04:00       Canada             M          75
# ...           ...       ...          ...           ...         ...
# 65533  15-02-2020  12:13:00        India             F          48
# 65534  15-02-2020  12:14:00       Canada             F          35
# 65535  15-02-2020  12:15:00          USA             M          41
# 65536  15-02-2020  12:16:00       Canada             F          63
# 65537  15-02-2020  12:17:00          USA             F          32
#
#       driver_race violation  search_conducted     search_type stop_outcome  \
# 0           Asian  Speeding              True  Vehicle Search       Ticket
# ...

# %%
data['stop_date'] = pd.to_datetime(data['stop_date'], errors='coerce')
data['stop_date_str'] = data['stop_date'].dt.strftime('%y-%m-%d')
data['stop_time'] = pd.to_datetime(data['stop_time'], errors='coerce')
data['stop_time_str'] = data['stop_time'].dt.strftime('%H-%M-%S')
# Out:
# C:\Users\A Prem kumar\AppData\Local\Temp\ipykernel_14900\4199409572.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['stop_time'] = pd.to_datetime(data['stop_time'], errors='coerce')

# %%
data['stop_date'] = pd.to_datetime(data['stop_date'], errors='coerce')
data['stop_date_str'] = data['stop_date'].dt.strftime('%y-%m-%d')
data['stop_time'] = pd.to_datetime(data['stop_time'], errors='coerce')
data['stop_time_str'] = data['stop_time'].dt.strftime('%H-%M-%S')

# %%
data
# Out:
#        stop_date           stop_time country_name driver_gender  driver_age  \
# 0     2020-01-01 2025-09-11 00:00:00       Canada             M          19
# 1     2020-01-01 2025-09-11 00:01:00        India             M          58
# 2     2020-01-01 2025-09-11 00:02:00          USA             M          76
# 3     2020-01-01 2025-09-11 00:03:00       Canada             M          76
# 4     2020-01-01 2025-09-11 00:04:00       Canada             M          75
# ...          ...                 ...          ...           ...         ...
# 65533        NaT 2025-09-11 12:13:00        India             F          48
# 65534        NaT 2025-09-11 12:14:00       Canada             F          35
# 65535        NaT 2025-09-11 12:15:00          USA             M          41
# 65536        NaT 2025-09-11 12:16:00       Canada             F          63
# 65537        NaT 2025-09-11 12:17:00          USA             F          32
#
# ...

# %%
data = data.where(pd.notnull(data), None)

# %%
insert_query = """
INSERT INTO police_logs (
    stop_date, stop_time, country_name, driver_gender, driver_age, driver_race,
    violation, search_conducted, search_type, stop_outcome, drugs_related_stop,
    stop_duration, vehicle_number, timestamp
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
data
# Out:
#        stop_date           stop_time country_name driver_gender  driver_age  \
# 0     2020-01-01 2025-09-11 00:00:00       Canada             M          19
# 1     2020-01-01 2025-09-11 00:01:00        India             M          58
# 2     2020-01-01 2025-09-11 00:02:00          USA             M          76
# 3     2020-01-01 2025-09-11 00:03:00       Canada             M          76
# 4     2020-01-01 2025-09-11 00:04:00       Canada             M          75
# ...          ...                 ...          ...           ...         ...
# 65533        NaT 2025-09-11 12:13:00        India             F          48
# 65534        NaT 2025-09-11 12:14:00       Canada             F          35
# 65535        NaT 2025-09-11 12:15:00          USA             M          41
# 65536        NaT 2025-09-11 12:16:00       Canada             F          63
# 65537        NaT 2025-09-11 12:17:00          USA             F          32
#
# ...

# %%
insert_query = """
INSERT INTO police_logs (
    stop_date, stop_time, country_name, driver_gender, driver_age, driver_race,
    violation, search_conducted, search_type, stop_outcome, drugs_related_stop,
    stop_duration, vehicle_number, timestamp
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""
conn.commit()

# %%
for _, row in data.iterrows():
    cursor.execute(insert_query, (
        row['stop_date'] if pd.notna(row['stop_date']) else None,
        row['stop_time'] if pd.notna(row['stop_time']) else None,
        row.get('country_name'),
        row.get('driver_gender'),
        int(row.get('driver_age')) if pd.notna(row.get('driver_age')) else None,
        row.get('driver_race'),
        row.get('violation'),
        row.get('search_conducted'),
        row.get('search_type'),
        row.get('stop_outcome'),
        row['drugs_related_stop'] if pd.notna(row['drugs_related_stop']) else None,
        row.get('stop_duration'),
        row.get('vehicle_number') if pd.notna(row.get('vehicle_number')) else f'VEH{row.name}',
        row.get('timestamp') if pd.notna(row.get('timestamp')) else None,
    ))

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import asyncio

# %%
# Out:
# (NaT, Timestamp('2025-09-10 00:00:00'), 'India', 'M', 58, 'Hispanic', 'Other', False, 'No', 'Warning', 1, '0-15 Min', 'GJ86UV9592', NaT)

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[35], line 2
#       1 for _, row in data.iterrows():
# ----> 2     cursor.execute(insert_query, (
#       3         row['stop_date'],
#       4         row['stop_time'],
#       5         row.get('country_name'),
#       6         row.get('driver_gender'),
#       7         int(row.get('driver_age')) if pd.notna(row.get('driver_age')) else None,
#       8         row.get('driver_race'),
#       9         row.get('violation'),
#      10         row.get('search_conducted'),
#      11         row.get('search_type'),
#      12         row.get('stop_outcome'),
#      13         row['drugs_related_stop'],
#      14         row.get('stop_duration'),
#      15         row.get('vehicle_number', f'VEH{row.name}'),
#      16         row.get('timestamp'),
#      17 ))
#
# ...

# %%
# Out:
# Timestamp('2020-01-01 00:00:00-1000', tz='UTC-10:00')

# %%
# Out:
# C:\Users\A Prem kumar\AppData\Local\Temp\ipykernel_21556\2638763896.py:1: PerformanceWarning: Adding/subtracting object-dtype array to DatetimeArray not vectorized.
#   data['timestamp'] = pd.to_datetime(data['stop_date'].dt.strftime('%Y-%m-%d') + ' ' + data['stop_time'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 data['timestamp'] = pd.to_datetime(data['stop_date'].dt.strftime('%Y-%m-%d') + ' ' + data['stop_time'])
#
# File c:\VSCODE\.venv\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\VSCODE\.venv\lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
# ...

# %%
# Out:
# drug_related_stop: None → None

# %%
# Out:
# Raw: 1 → None

# %%
# Out:
# [1 0]

# %%
# Out:
# 1

# %%
# Out:
# Inserted row 17280

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[211], line 2
#       1 for _, row in data.iterrows():
# ----> 2     cursor.execute(insert_query, (
#       3         row['stop_date'],
#       4         row['stop_time'],
#       5         row.get('country_name'),
#       6         row.get('driver_gender'),
#       7         int(row.get('driver_age')) if pd.notna(row.get('driver_age')) else None,
#       8         row.get('driver_race'),
#       9         row.get('violation'),
#      10         row.get('search_conducted'),
#      11         row.get('search_type'),
#      12         row.get('stop_outcome'),
#      13         row['drugs_related_stop'],
#      14         row.get('stop_duration'),
#      15         row.get('vehicle_number', f'VEH{row.name}'),
#      16         row.get('timestamp'),
#      17 ))
#
# ...

# %%
for col in ['stop_date', 'stop_time', 'timestamp']:
    data[col] = data[col].apply(lambda x: x if pd.notna(x) else None)

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[214], line 2
#       1 for _, row in data.iterrows():
# ----> 2     cursor.execute(insert_query, (
#       3         row['stop_date'],
#       4         row['stop_time'],
#       5         row.get('country_name'),
#       6         row.get('driver_gender'),
#       7         int(row.get('driver_age')) if pd.notna(row.get('driver_age')) else None,
#       8         row.get('driver_race'),
#       9         row.get('violation'),
#      10         row.get('search_conducted'),
#      11         row.get('search_type'),
#      12         row.get('stop_outcome'),
#      13         row['drugs_related_stop'],
#      14         row.get('stop_duration'),
#      15         row.get('vehicle_number', f'VEH{row.name}'),
#      16         row.get('timestamp'),
#      17 ))
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[216], line 2
#       1 for _, row in data.iterrows():
# ----> 2     cursor.execute(insert_query, (
#       3         row['stop_date'],
#       4         row['stop_time'],
#       5         row.get('country_name'),
#       6         row.get('driver_gender'),
#       7         int(row.get('driver_age')) if pd.notna(row.get('driver_age')) else None,
#       8         row.get('driver_race'),
#       9         row.get('violation'),
#      10         row.get('search_conducted'),
#      11         row.get('search_type'),
#      12         row.get('stop_outcome'),
#      13         row['drugs_related_stop'],
#      14         row.get('stop_duration'),
#      15         row.get('vehicle_number', f'VEH{row.name}'),
#      16         row.get('timestamp'),
#      17 ))
#
# ...
